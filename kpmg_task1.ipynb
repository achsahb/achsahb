# %% [markdown]
# <a href="https://colab.research.google.com/github/achsahb/achsahb/blob/main/kpmg_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data quality assessment of KPMG Analytics.There are 3 datasets present
#
# 1.   Customer Addresses
# 1.   Transaction data in the past three months
# 2.   Customer Demographic

# %%
import pandas as pd

# %% [markdown]
# To load the data and view the contents of the data

# %%
df = pd.read_excel('/content/drive/MyDrive/KPMG.xlsx')

# %%
df
# Out:
#     Unnamed: 0  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 93         NaN
# 94         NaN
# 95         NaN
# 96         NaN
# 97         NaN
#
#     Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only.   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# ...

# %% [markdown]
# To select a particular sheet, here we are selecting "Transactions"

# %%
df = pd.read_excel('/content/drive/MyDrive/KPMG.xlsx', sheet_name="Transactions")

# %%
df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                 1.0         2.0       2950.0       2017-02-25           0.0
# 1                 2.0         3.0       3120.0       2017-05-21           1.0
# 2                 3.0        37.0        402.0       2017-10-16           0.0
# 3                 4.0        88.0       3135.0       2017-08-31           0.0
# 4                 5.0        78.0        787.0       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19995         19996.0        51.0       1018.0       2017-06-24           1.0
# 19996         19997.0        41.0        127.0       2017-11-09           1.0
# 19997         19998.0        87.0       2284.0       2017-04-14           1.0
# 19998         19999.0         6.0       2764.0       2017-07-03           0.0
# 19999         20000.0        11.0       1144.0       2017-09-22           1.0
#
# ...

# %% [markdown]
# To see only the first few rows of the data, by default when we use head() it'll show us the first 5 records.

# %%
df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0             1.0         2.0       2950.0       2017-02-25           0.0
# 1             2.0         3.0       3120.0       2017-05-21           1.0
# 2             3.0        37.0        402.0       2017-10-16           0.0
# 3             4.0        88.0       3135.0       2017-08-31           0.0
# 4             5.0        78.0        787.0       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %% [markdown]
# to get the information.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  float64
#  1   product_id               20000 non-null  float64
#  2   customer_id              20000 non-null  float64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %% [markdown]
# Let's check the date and set the date in proper format

# %%
df['product_first_sold_date']=pd.to_datetime(df['product_first_sold_date']).dt.date

# %%
df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0             1.0         2.0       2950.0       2017-02-25           0.0
# 1             2.0         3.0       3120.0       2017-05-21           1.0
# 2             3.0        37.0        402.0       2017-10-16           0.0
# 3             4.0        88.0       3135.0       2017-08-31           0.0
# 4             5.0        78.0        787.0       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date
# ...

# %%
df.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost
# count   19803.000000
# mean      556.046951
# std       405.955660
# min         7.210000
# 25%       215.140000
# 50%       507.580000
# 75%       795.100000
# max      1759.850000

# %% [markdown]
# Checking for null values

# %%
df.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %% [markdown]
# to get all the columns

# %%
df.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
df['online_order'].value_counts()
# Out:
# 1.0    9829
# 0.0    9811
# Name: online_order, dtype: int64

# %%
df['order_status'].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
df['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %% [markdown]
# to check for duplicate values in the data

# %%
d=df.duplicated()
df[d].sum()
# Out:
# <ipython-input-144-7a7915398da5>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[d].sum()
# transaction_id             0.0
# product_id                 0.0
# customer_id                0.0
# online_order               0.0
# order_status               0.0
# brand                      0.0
# product_line               0.0
# product_class              0.0
# product_size               0.0
# list_price                 0.0
# standard_cost              0.0
# product_first_sold_date    0.0
# dtype: float64

# %% [markdown]
# Now working with NewCustomerList

# %%
df1 = pd.read_excel('/content/drive/MyDrive/KPMG.xlsx', sheet_name="NewCustomerList")
# Out:
# <ipython-input-145-3a99c3af9799>:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   df1 = pd.read_excel('/content/drive/MyDrive/KPMG.xlsx', sheet_name="NewCustomerList")

# %%
df1.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   float64
# ...

# %% [markdown]
# drop the unammed columns in the dataset as their information is present.So drop the unammed 16,unammed 17, unnamed 18, unnamed 19 and unnamed 20 i.e., 5 columns

# %%
cols = ['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19' ,'Unnamed: 20']

# %%
df1.drop(cols,axis=1,inplace=True)

# %%
df1.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes    14.0     45 Shopko Center
# ...

# %%
df1.describe()
# Out:
#        past_3_years_bike_related_purchases       tenure     postcode  \
# count                          1000.000000  1000.000000  1000.000000
# mean                             49.836000    11.388000  3019.227000
# std                              27.796686     5.037145   848.895767
# min                               0.000000     0.000000  2000.000000
# 25%                              26.750000     7.000000  2209.000000
# 50%                              51.000000    11.000000  2800.000000
# 75%                              72.000000    15.000000  3845.500000
# max                              99.000000    22.000000  4879.000000
#
#        property_valuation         Rank        Value
# count         1000.000000  1000.000000  1000.000000
# mean             7.397000   498.819000     0.881714
# std              2.758804   288.810997     0.293525
# min              1.000000     1.000000     0.340000
# 25%              6.000000   250.000000     0.649531
# ...

# %%
df1.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Rank', 'Value'],
#       dtype='object')

# %%
df1['gender'].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %% [markdown]
# Replace the gender where 'U' is there with 'Unspecified' for better understanding

# %%
df1['gender'].str.replace('U','Unspecified')
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 995      Male
# 996      Male
# 997    Female
# 998      Male
# 999      Male
# Name: gender, Length: 1000, dtype: object

# %% [markdown]
# The CustomerDemographic data

# %%
cust = pd.read_excel('/content/drive/MyDrive/KPMG.xlsx', sheet_name="CustomerDemographic")
# Out:
# <ipython-input-157-8c620e1add03>:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   cust = pd.read_excel('/content/drive/MyDrive/KPMG.xlsx', sheet_name="CustomerDemographic")

# %%
cust.head(5)
# Out:
#    customer_id      first_name  last_name  gender  \
# 0          1.0         Laraine  Medendorp       F
# 1          2.0             Eli    Bockman    Male
# 2          3.0           Arlin     Dearle    Male
# 3          4.0          Talbot        NaN    Male
# 4          5.0  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                 93.0 1953-10-12     Executive Secretary
# 1                                 81.0 1980-12-16  Administrative Officer
# 2                                 61.0 1954-01-20      Recruiting Manager
# 3                                 33.0 1961-10-03                     NaN
# 4                                 56.0 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
cust['default']
cust.drop(['default'],axis=1)
# Out:
#       customer_id      first_name  last_name  gender  \
# 0             1.0         Laraine  Medendorp       F
# 1             2.0             Eli    Bockman    Male
# 2             3.0           Arlin     Dearle    Male
# 3             4.0          Talbot        NaN    Male
# 4             5.0  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995       3996.0         Rosalia   Halgarth  Female
# 3996       3997.0          Blanch     Nisuis  Female
# 3997       3998.0          Sarene    Woolley       U
# 3998       3999.0       Patrizius        NaN    Male
# 3999       4000.0           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                    93.0 1953-10-12     Executive Secretary
# 1                                    81.0 1980-12-16  Administrative Officer
# 2                                    61.0 1954-01-20      Recruiting Manager
# ...

# %%
cust.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0          1.0         Laraine  Medendorp       F
# 1          2.0             Eli    Bockman    Male
# 2          3.0           Arlin     Dearle    Male
# 3          4.0          Talbot        NaN    Male
# 4          5.0  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                 93.0 1953-10-12     Executive Secretary
# 1                                 81.0 1980-12-16  Administrative Officer
# 2                                 61.0 1954-01-20      Recruiting Manager
# 3                                 33.0 1961-10-03                     NaN
# 4                                 56.0 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  \
# 0                Health      Mass Customer                  N
# 1    Financial Services      Mass Customer                  N
# ...

# %%
cust.describe()
# Out:
#        customer_id  past_3_years_bike_related_purchases       tenure
# count  4000.000000                          4000.000000  3913.000000
# mean   2000.500000                            48.890000    10.657041
# std    1154.844867                            28.715005     5.660146
# min       1.000000                             0.000000     1.000000
# 25%    1000.750000                            24.000000     6.000000
# 50%    2000.500000                            48.000000    11.000000
# 75%    3000.250000                            73.000000    15.000000
# max    4000.000000                            99.000000    22.000000

# %%
cust.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
cust.duplicated().sum()
# Out:
# 0

# %%
cust['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# F            1
# Femal        1
# M            1
# Name: gender, dtype: int64

# %% [markdown]
# we'll divide it into 3 categories by correcting the spelling and giving the same name which belongs to same category.

# %%
cust['gender']=cust['gender'].replace('F','Female').replace('M','Male').replace('Femal','Female').replace('U','Unspecified')

# %%
cust['gender'].value_counts()
# Out:
# Female         2039
# Male           1873
# Unspecified      88
# Name: gender, dtype: int64

# %%
cust.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
cust['customer_id'].iloc[-1]
# Out:
# 4000.0
